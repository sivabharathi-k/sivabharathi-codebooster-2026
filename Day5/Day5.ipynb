# %% [markdown]
# <a href="https://colab.research.google.com/github/sivabharathi-k/sivabharathi-codebooster-2026/blob/main/Day5/Day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import all required libraies

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score

# %%
#load the student dataset

df=pd.read_excel('student_performance_dataset.xlsx')
print(f'Dataset loaded:{df.shape[0]},students,{df.shape[1]}Columns')
print(f'Coulmns:{df.columns.tolist()}')
print(f'\nMissing values:{df.isnull().sum().sum()}')
print('\nFirst 5 rows:')
df.head()
# Out:
# Dataset loaded:50,students,7Columns
# Coulmns:['name', 'gender', 'department', 'math_score', 'programming_score', 'attendance_percentage', 'total_score']
#
# Missing values:1
#
# First 5 rows:
#        name gender department  math_score  programming_score  \
# 0  Udhaya_1   Male        CSE          92                 57
# 1   Eswar_2   Male       AIDS          50                 77
# 2    Arun_3   Male        NaN          59                 72
# 3  Raghul_4   Male       AIDS          71                 54
# 4  Ishwar_5   Male         IT          89                 67
#
#    attendance_percentage  total_score
# 0                  73.57          149
# 1                  79.77          127
# 2                  86.07          131
# 3                  80.72          125
# 4                  76.91          156

# %%
#understand the prediction task

print(df['programming_score'].describe())
# Out:
# count     50.000000
# mean      69.740000
# std       18.405645
# min       40.000000
# 25%       54.000000
# 50%       70.500000
# 75%       85.750000
# max      100.000000
# Name: programming_score, dtype: float64

# %%
#feature Engineering: encode categorical columns
df_ml =df.copy()
le_gender=LabelEncoder()
df_ml['gender_encoded']=le_gender.fit_transform(df_ml['gender'])
print(f'Gender encodeing:{dict(zip(le_gender.classes_,le_gender.transform(le_gender.classes_)))}')
le_dept=LabelEncoder()
df_ml['dept_encoded']=le_dept.fit_transform(df_ml['department'])
print(f'\nDepartment encoding:{dict(zip(le_dept.classes_,le_dept.transform(le_dept.classes_)))}')
print('\nNew columns added: gender_encoded,department_encoded')
df_ml[['gender','gender_encoded','department','dept_encoded']].head()
# Out:
# Gender encodeing:{'Female': np.int64(0), 'Male': np.int64(1)}
#
# Department encoding:{'AIDS': np.int64(0), 'CSE': np.int64(1), 'ECE': np.int64(2), 'EEE': np.int64(3), 'IT': np.int64(4), nan: np.int64(5)}
#
# New columns added: gender_encoded,department_encoded
#   gender  gender_encoded department  dept_encoded
# 0   Male               1        CSE             1
# 1   Male               1       AIDS             0
# 2   Male               1        NaN             5
# 3   Male               1       AIDS             0
# 4   Male               1         IT             4

# %%
feature_cols = [
    'math_score',
    'attendance_percentage',
    'gender_encoded',
    'dept_encoded'
]

x=df_ml[feature_cols]
y=df_ml['programming_score']

print(f'Feature matrix x shape: {x.shape} (students x features)')
print(f'Target vector y shape: {y.shape}  (one score per students)')
print(f'\nFeature columns: {feature_cols}')
print(f'Target column    : programming_score')
print(f'\nTarget range:  {y.min()} to {y.max()} (mean: {y.mean():.1f})')
# Out:
# Feature matrix x shape: (50, 4) (students x features)
# Target vector y shape: (50,)  (one score per students)
#
# Feature columns: ['math_score', 'attendance_percentage', 'gender_encoded', 'dept_encoded']
# Target column    : programming_score
#
# Target range:  40 to 100 (mean: 69.7)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
print(f'Total students   : {len(X)}')
print(f'Training_students: {len(X_train)} ({len(X_train)/len(x)*100:.0f}%)')
print(f'Testing_students : {len(X_test)} ({len(X_test)/len(X)*100:.0f}%)')
print(f'\nTraining target range:  {y_train.min()} - {y_train.max()} ')
print(f'Testing target range:   {y_test.min()} - {y_test.max()} ')
# Out:
# Total students   : 50
# Training_students: 40 (80%)
# Testing_students : 10 (20%)
#
# Training target range:  40 - 100
# Testing target range:   44 - 94

# %%
print('Mean of training features:\n', X_train.mean())
print('\nStandard deviation of training features:\n', X_train.std())
# Out:
# Mean of training features:
#  math_score               68.60000
# attendance_percentage    80.91175
# gender_encoded            0.67500
# dept_encoded              1.82500
# dtype: float64
#
# Standard deviation of training features:
#  math_score               15.780221
# attendance_percentage     9.919254
# gender_encoded            0.474342
# dept_encoded              1.583367
# dtype: float64

# %%
print('Total mean of training features:', X_train.values.mean())
# Out:
# Total mean of training features: 38.002937499999994

# %%
#Train model 1: Linear Regression
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

lr_model = LinearRegression()
lr_model.fit(X_train, y_train)
lr_pred = lr_model.predict(X_test)

#Evaluate
lr_mae=mean_absolute_error(y_test,lr_pred)
lr_rmse=np.sqrt(mean_squared_error(y_test,lr_pred))
lr_r2=r2_score(y_test,lr_pred)

print('=== Model 1: Linear Regression ===')
print(f'MAE: {lr_mae:.2f}')
print(f'RMSE: {lr_rmse:.2f}')
print(f'R2: {lr_r2:.2f}')
print()
print('Learned coefficents')
for feature, coef in zip(feature_cols, lr_model.coef_):
    print(f'{feature}: {coef:.2f}')
print(f'Intercept: {lr_model.intercept_:.2f}')
# Out:
# === Model 1: Linear Regression ===
# MAE: 18.75
# RMSE: 21.53
# R2: -0.57
#
# Learned coefficents
# math_score: 0.19
# attendance_percentage: -0.27
# gender_encoded: -8.04
# dept_encoded: 0.87
# Intercept: 84.03
