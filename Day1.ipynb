# %% [markdown]
# <a href="https://colab.research.google.com/github/sivabharathi-k/sivabharathi-codebooster-2026/blob/main/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
df=pd.read_csv("student_performance.csv")
print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_695/4277869021.py in <cell line: 0>()
# ----> 1 df=pd.read_csv("student_performance.csv")
#       2 print(df)
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df.head()

# %%
df.tail()

# %%
print(df.shape)
print(df.shape[0])
print(df.shape[1])

# %%
print(df.columns.tolist())

# %%
print(df.dtypes)

# %%
df.describe()

# %%
print(df.isnull().sum())

# %%
print(df['name'])

# %%
print(df["department"].unique())

# %%
print(df["department"].value_counts())

# %%
cs_students=df[df['department']=='Computer Science']
print(len(cs_students))
#print(cs_students[['name','math_score','programming_score','admission_year']])
#print(cs_students[cs_students['attendance_percentage'] > 90]

# %%
cs_students1=df[df['attendance_percentage']>90]

print(cs_students1[['name','attendance_percentage']])

# %%
df['total_score']=df['math_score']+df['english_score']+df['programming_score']+df['science_score']
toppers=df[df['total_score']/4>70]
print(toppers[['name','total_score','department']])
print(len)

# %%
dept_avg = toppers.groupby('department')['math_score'].mean()
print(dept_avg[:])
